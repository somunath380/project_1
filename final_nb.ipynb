# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# %%
df=pd.read_csv('final_df.csv')
df.head()
# Out:
#    selling_price  km_driven  max_power  seats  mileage_num  engine_num  \
# 0         450000     145500      74.00      5         23.4        1248
# 1         370000     120000     103.52      5         21.1        1498
# 2         158000     140000      78.00      5         17.7        1497
# 3         225000     127000      90.00      5         23.0        1396
# 4         130000     120000      88.20      5         16.1        1298
#
#    torque_NM  torque_rpm  no_year  fuel_Diesel  fuel_LPG  fuel_Petrol  \
# 0      190.0      2000.0        7            1         0            0
# 1      250.0      2000.0        7            1         0            0
# 2       12.7      2700.0       15            0         0            1
# 3       22.4      2250.0       11            1         0            0
# 4       11.5      4500.0       14            0         0            1
#
#    seller_type_Individual  seller_type_Trustmark Dealer  transmission_Manual  \
# 0                       1                             0                    1
# 1                       1                             0                    1
# 2                       1                             0                    1
# 3                       1                             0                    1
# 4                       1                             0                    1
#
#    owner_Fourth & Above Owner  owner_Second Owner  owner_Test Drive Car  \
# 0                           0                   0                     0
# 1                           0                   1                     0
# 2                           0                   0                     0
# 3                           0                   0                     0
# 4                           0                   0                     0
#
#    owner_Third Owner
# 0                  0
# 1                  0
# 2                  1
# 3                  0
# 4                  0

# %%
df.describe()
# Out:
#        selling_price     km_driven    max_power        seats  mileage_num  \
# count   8.128000e+03  8.128000e+03  8128.000000  8128.000000  8128.000000
# mean    6.382718e+05  6.981951e+04    91.325514     5.405389    19.434461
# std     8.062534e+05  5.655055e+04    35.290213     0.948874     3.879938
# min     2.999900e+04  1.000000e+00    32.800000     2.000000     9.000000
# 25%     2.549990e+05  3.500000e+04    69.000000     5.000000    16.800000
# 50%     4.500000e+05  6.000000e+04    82.000000     5.000000    19.300000
# 75%     6.750000e+05  9.800000e+04   101.250000     5.000000    22.225000
# max     1.000000e+07  2.360457e+06   400.000000    14.000000    42.000000
#
#        engine_num    torque_NM    torque_rpm      no_year  fuel_Diesel  \
# count  8128.00000  8128.000000   8128.000000  8128.000000  8128.000000
# mean   1452.89813   167.928307   2871.707493     7.195989     0.541585
# std     498.19672    95.999888    972.588426     4.044249     0.498298
# min     624.00000     4.800000    500.000000     1.000000     0.000000
# 25%    1197.00000   104.000000   2100.000000     4.000000     0.000000
# 50%    1248.00000   154.900000   2500.000000     6.000000     1.000000
# 75%    1582.00000   200.000000   4000.000000    10.000000     1.000000
# max    3604.00000   789.000000  21800.000000    38.000000     1.000000
#
#           fuel_LPG  fuel_Petrol  seller_type_Individual  \
# count  8128.000000  8128.000000             8128.000000
# mean      0.004675     0.446727                0.832431
# std       0.068220     0.497185                0.373506
# min       0.000000     0.000000                0.000000
# 25%       0.000000     0.000000                1.000000
# 50%       0.000000     0.000000                1.000000
# 75%       0.000000     1.000000                1.000000
# max       1.000000     1.000000                1.000000
#
#        seller_type_Trustmark Dealer  transmission_Manual  \
# count                   8128.000000          8128.000000
# mean                       0.029035             0.870817
# std                        0.167916             0.335423
# min                        0.000000             0.000000
# 25%                        0.000000             1.000000
# 50%                        0.000000             1.000000
# 75%                        0.000000             1.000000
# max                        1.000000             1.000000
#
#        owner_Fourth & Above Owner  owner_Second Owner  owner_Test Drive Car  \
# count                 8128.000000         8128.000000           8128.000000
# mean                     0.021407            0.258981              0.000615
# std                      0.144747            0.438102              0.024796
# min                      0.000000            0.000000              0.000000
# 25%                      0.000000            0.000000              0.000000
# 50%                      0.000000            0.000000              0.000000
# 75%                      0.000000            1.000000              0.000000
# max                      1.000000            1.000000              1.000000
#
#        owner_Third Owner
# count        8128.000000
# mean            0.068282
# std             0.252246
# min             0.000000
# 25%             0.000000
# 50%             0.000000
# 75%             0.000000
# max             1.000000

# %%
df.isnull().sum()
# Out:
# selling_price                   0
# km_driven                       0
# max_power                       0
# seats                           0
# mileage_num                     0
# engine_num                      0
# torque_NM                       0
# torque_rpm                      0
# no_year                         0
# fuel_Diesel                     0
# fuel_LPG                        0
# fuel_Petrol                     0
# seller_type_Individual          0
# seller_type_Trustmark Dealer    0
# transmission_Manual             0
# owner_Fourth & Above Owner      0
# owner_Second Owner              0
# owner_Test Drive Car            0
# owner_Third Owner               0
# dtype: int64

# %%
X = df.iloc[:,1:]
y = df.iloc[:,1]

# %%
X.head()
# Out:
#    km_driven  max_power  seats  mileage_num  engine_num  torque_NM  \
# 0     145500      74.00      5         23.4        1248      190.0
# 1     120000     103.52      5         21.1        1498      250.0
# 2     140000      78.00      5         17.7        1497       12.7
# 3     127000      90.00      5         23.0        1396       22.4
# 4     120000      88.20      5         16.1        1298       11.5
#
#    torque_rpm  no_year  fuel_Diesel  fuel_LPG  fuel_Petrol  \
# 0      2000.0        7            1         0            0
# 1      2000.0        7            1         0            0
# 2      2700.0       15            0         0            1
# 3      2250.0       11            1         0            0
# 4      4500.0       14            0         0            1
#
#    seller_type_Individual  seller_type_Trustmark Dealer  transmission_Manual  \
# 0                       1                             0                    1
# 1                       1                             0                    1
# 2                       1                             0                    1
# 3                       1                             0                    1
# 4                       1                             0                    1
#
#    owner_Fourth & Above Owner  owner_Second Owner  owner_Test Drive Car  \
# 0                           0                   0                     0
# 1                           0                   1                     0
# 2                           0                   0                     0
# 3                           0                   0                     0
# 4                           0                   0                     0
#
#    owner_Third Owner
# 0                  0
# 1                  0
# 2                  1
# 3                  0
# 4                  0

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor()
knn.fit(X_train.to_numpy(),y_train.to_numpy())
# Out:
# KNeighborsRegressor()

# %%
print('train score', knn.score(X_train.to_numpy(),y_train.to_numpy()))
print('test score', knn.score(X_test.to_numpy(), y_test.to_numpy()))
# Out:
# train score 0.9161548167551903
# test score 0.9996262288216147

# %%
predictions = knn.predict(X_test.to_numpy())

# %%
plt.scatter(y_test,predictions)

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 113.29040590405909
# MSE: 981418.4298892985
# RMSE: 990.6656498987428

# %%
import pickle
# open a file, where you ant to store the data
file = open('knn.pkl', 'wb')

# dump information to that file
pickle.dump(knn, file)
